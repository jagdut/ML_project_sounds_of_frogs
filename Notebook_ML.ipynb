# %% [markdown]
# <a href="https://colab.research.google.com/github/jagdut/ML_project_sounds_of_frogs/blob/main/Notebook_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Projekt na ML- rozpoznawanie dźwięków pochodzących od żab

# %%
import torch
